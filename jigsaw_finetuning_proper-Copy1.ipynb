# %%
import torch

from data import data_helper
from data.data_helper import available_datasets
from models import model_factory
from optimizer.optimizer_helper import get_optim_and_scheduler
from torch.nn import functional as F
from torch import nn

from utils.Logger import Logger

import torchvision
import matplotlib.pyplot as plt

from train_jigsaw import do_training


batch_size = 128
num_workers = 4
jig_classes = 31
class_classes = 31
lr = 0.001
epochs = 30
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
office_list = ["amazon","dslr","webcam"]
source = ["amazon"]
target = "dslr"
dataloaders = {"train": data_helper.get_dataloader(source, jig_classes, "train"),
           "val": data_helper.get_dataloader(target, jig_classes, "val")}
dataset_sizes = {"train": len(dataloaders["train"].dataset),
                "val": len(dataloaders["val"].dataset)}
print(dataset_sizes)
# Out:
# Using multiple sources
# {'train': 2817, 'val': 498}

# %%
def get_optim_and_scheduler(network, epochs, lr):
    from torch import optim
    optimizer = optim.SGD(network.parameters(), weight_decay=.0005, momentum=.9, nesterov=True, lr=lr)
    step_size = int(epochs * .9)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_size)
    print(step_size)
    return optimizer, scheduler

model_ft = model_factory.get_network("caffenet")(jigsaw_classes=jig_classes, classes=class_classes)
model_ft = model_ft.to(device)

optimizer, scheduler = get_optim_and_scheduler(model_ft, epochs, lr)
# Out:
# 27

# %%
def do_epoch(model, source, target, optimizer, logger, device):
    criterion = nn.CrossEntropyLoss()
    model.train()
    for it, ((data, jig_l, class_l), d_idx) in enumerate(source):
        data, jig_l, class_l = data.to(device), jig_l.to(device), class_l.to(device)
        
        optimizer.zero_grad()
        
        jigsaw_logit, class_logit = model(data)
        jigsaw_loss = criterion(jigsaw_logit, jig_l)
        class_loss = criterion(class_logit[d_idx==0], class_l[d_idx==0])
        _, cls_pred = class_logit.max(dim=1)
        _, jig_pred = jigsaw_logit.max(dim=1)
        loss = class_loss + jigsaw_loss * jig_weight
        
        loss.backward()
        optimizer.step()

        logger.log(it, len(source), {"jigsaw": jigsaw_loss, "class": class_loss},
                  {"jigsaw": torch.sum(jig_pred == jig_l.data).item(), "class":torch.sum(cls_pred == class_l.data).item()},
                  data.shape[0])

    model.eval()
    with torch.no_grad():
        jigsaw_correct = 0
        class_correct = 0
        total = 0
        for it, ((data, jig_l, class_l), d_idx) in enumerate(target):
            data, jig_l, class_l = data.to(device), jig_l.to(device), class_l.to(device)
            jigsaw_logit, class_logit = model(data)
            _, cls_pred = class_logit.max(dim=1)
            _, jig_pred = jigsaw_logit.max(dim=1)
            class_correct += torch.sum(cls_pred == class_l.data)
            jigsaw_correct += torch.sum(jig_pred == jig_l.data)
            total += data.shape[0]
        logger.log_test({"jigsaw": float(jigsaw_correct) / total,
                         "class": float(class_correct) / total})


def do_training(epochs, model, source, target, optimizer, scheduler, device):
    logger = Logger(epochs)
    for k in range(epochs):
        scheduler.step()
        logger.new_epoch(scheduler.get_lr())
        do_epoch(model, source, target, optimizer, logger, device)
    return logger, model

# %%
jig_weight = 0.1
logger, model = do_training(epochs, model_ft, dataloaders["train"], dataloaders["val"], optimizer, scheduler, device)
# Out:
# New epoch - lr: 0.001
# 0/22 of epoch 1/30 jigsaw : 3.480208, class : 3.475472 - acc jigsaw : 0.023438, class : 0.039062 [bs:128]
# 10/22 of epoch 1/30 jigsaw : 3.435659, class : 3.106822 - acc jigsaw : 0.015625, class : 0.203125 [bs:128]
# 20/22 of epoch 1/30 jigsaw : 3.443415, class : 2.342355 - acc jigsaw : 0.023438, class : 0.375000 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.238956
# New epoch - lr: 0.001
# 0/22 of epoch 2/30 jigsaw : 3.452118, class : 2.539809 - acc jigsaw : 0.046875, class : 0.265625 [bs:128]
# 10/22 of epoch 2/30 jigsaw : 3.382023, class : 2.326408 - acc jigsaw : 0.085938, class : 0.343750 [bs:128]
# 20/22 of epoch 2/30 jigsaw : 3.389437, class : 2.028787 - acc jigsaw : 0.062500, class : 0.398438 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.325301
# New epoch - lr: 0.001
# 0/22 of epoch 3/30 jigsaw : 3.364558, class : 1.718453 - acc jigsaw : 0.070312, class : 0.515625 [bs:128]
# 10/22 of epoch 3/30 jigsaw : 3.331082, class : 1.840799 - acc jigsaw : 0.117188, class : 0.507812 [bs:128]
# 20/22 of epoch 3/30 jigsaw : 3.290464, class : 1.871942 - acc jigsaw : 0.109375, class : 0.546875 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.343373
# New epoch - lr: 0.001
# 0/22 of epoch 4/30 jigsaw : 3.313938, class : 1.863862 - acc jigsaw : 0.125000, class : 0.476562 [bs:128]
# 10/22 of epoch 4/30 jigsaw : 3.281501, class : 1.716100 - acc jigsaw : 0.117188, class : 0.476562 [bs:128]
# 20/22 of epoch 4/30 jigsaw : 3.310167, class : 1.259072 - acc jigsaw : 0.085938, class : 0.671875 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.365462
# New epoch - lr: 0.001
# 0/22 of epoch 5/30 jigsaw : 3.296705, class : 1.576778 - acc jigsaw : 0.093750, class : 0.539062 [bs:128]
# 10/22 of epoch 5/30 jigsaw : 3.245876, class : 1.640418 - acc jigsaw : 0.140625, class : 0.546875 [bs:128]
# 20/22 of epoch 5/30 jigsaw : 3.282392, class : 1.810407 - acc jigsaw : 0.062500, class : 0.539062 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.365462
# New epoch - lr: 0.001
# 0/22 of epoch 6/30 jigsaw : 3.236053, class : 1.387829 - acc jigsaw : 0.125000, class : 0.554688 [bs:128]
# 10/22 of epoch 6/30 jigsaw : 3.206261, class : 1.685824 - acc jigsaw : 0.187500, class : 0.523438 [bs:128]
# 20/22 of epoch 6/30 jigsaw : 3.173645, class : 1.414962 - acc jigsaw : 0.093750, class : 0.578125 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.377510
# New epoch - lr: 0.001
# 0/22 of epoch 7/30 jigsaw : 3.206920, class : 1.408794 - acc jigsaw : 0.101562, class : 0.625000 [bs:128]
# 10/22 of epoch 7/30 jigsaw : 3.210538, class : 1.467111 - acc jigsaw : 0.148438, class : 0.578125 [bs:128]
# 20/22 of epoch 7/30 jigsaw : 3.216290, class : 1.305390 - acc jigsaw : 0.140625, class : 0.585938 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.345382
# New epoch - lr: 0.001
# 0/22 of epoch 8/30 jigsaw : 3.154675, class : 1.393115 - acc jigsaw : 0.195312, class : 0.625000 [bs:128]
# 10/22 of epoch 8/30 jigsaw : 3.123430, class : 1.315953 - acc jigsaw : 0.242188, class : 0.617188 [bs:128]
# 20/22 of epoch 8/30 jigsaw : 3.116282, class : 1.639501 - acc jigsaw : 0.195312, class : 0.484375 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.395582
# New epoch - lr: 0.001
# 0/22 of epoch 9/30 jigsaw : 3.080692, class : 1.359517 - acc jigsaw : 0.218750, class : 0.617188 [bs:128]
# 10/22 of epoch 9/30 jigsaw : 3.068026, class : 1.127273 - acc jigsaw : 0.203125, class : 0.632812 [bs:128]
# 20/22 of epoch 9/30 jigsaw : 3.095514, class : 1.566754 - acc jigsaw : 0.179688, class : 0.562500 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.367470
# New epoch - lr: 0.001
# 0/22 of epoch 10/30 jigsaw : 3.126213, class : 1.177823 - acc jigsaw : 0.226562, class : 0.687500 [bs:128]
# 10/22 of epoch 10/30 jigsaw : 3.051461, class : 1.234545 - acc jigsaw : 0.218750, class : 0.617188 [bs:128]
# 20/22 of epoch 10/30 jigsaw : 3.071084, class : 1.439080 - acc jigsaw : 0.140625, class : 0.593750 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.387550
# New epoch - lr: 0.001
# 0/22 of epoch 11/30 jigsaw : 3.112705, class : 1.151250 - acc jigsaw : 0.171875, class : 0.695312 [bs:128]
# 10/22 of epoch 11/30 jigsaw : 3.045679, class : 1.453854 - acc jigsaw : 0.218750, class : 0.531250 [bs:128]
# 20/22 of epoch 11/30 jigsaw : 3.060572, class : 1.322981 - acc jigsaw : 0.179688, class : 0.625000 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.381526
# New epoch - lr: 0.001
# 0/22 of epoch 12/30 jigsaw : 3.087078, class : 1.076049 - acc jigsaw : 0.179688, class : 0.671875 [bs:128]
# 10/22 of epoch 12/30 jigsaw : 3.024073, class : 1.157719 - acc jigsaw : 0.234375, class : 0.656250 [bs:128]
# 20/22 of epoch 12/30 jigsaw : 3.122704, class : 1.289804 - acc jigsaw : 0.109375, class : 0.625000 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.369478
# New epoch - lr: 0.001
# 0/22 of epoch 13/30 jigsaw : 3.054913, class : 1.424278 - acc jigsaw : 0.210938, class : 0.648438 [bs:128]
# 10/22 of epoch 13/30 jigsaw : 3.098529, class : 1.080279 - acc jigsaw : 0.203125, class : 0.695312 [bs:128]
# 20/22 of epoch 13/30 jigsaw : 2.952848, class : 1.106784 - acc jigsaw : 0.273438, class : 0.710938 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.387550
# New epoch - lr: 0.001
# 0/22 of epoch 14/30 jigsaw : 2.971824, class : 1.059284 - acc jigsaw : 0.234375, class : 0.679688 [bs:128]
# 10/22 of epoch 14/30 jigsaw : 2.951300, class : 0.930928 - acc jigsaw : 0.242188, class : 0.734375 [bs:128]
# 20/22 of epoch 14/30 jigsaw : 2.972444, class : 1.221015 - acc jigsaw : 0.210938, class : 0.664062 [bs:128]
# Accuracies on target: jigsaw : 0.004016, class : 0.391566
# New epoch - lr: 0.001
# 0/22 of epoch 15/30 jigsaw : 2.970089, class : 1.147169 - acc jigsaw : 0.273438, class : 0.625000 [bs:128]
# 10/22 of epoch 15/30 jigsaw : 2.912435, class : 0.965030 - acc jigsaw : 0.257812, class : 0.687500 [bs:128]
# 20/22 of epoch 15/30 jigsaw : 2.953083, class : 1.099800 - acc jigsaw : 0.242188, class : 0.648438 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.377510
# New epoch - lr: 0.001
# 0/22 of epoch 16/30 jigsaw : 2.942125, class : 1.008859 - acc jigsaw : 0.234375, class : 0.671875 [bs:128]
# 10/22 of epoch 16/30 jigsaw : 3.013326, class : 1.117063 - acc jigsaw : 0.218750, class : 0.687500 [bs:128]
# 20/22 of epoch 16/30 jigsaw : 2.910006, class : 0.950275 - acc jigsaw : 0.234375, class : 0.671875 [bs:128]
# Accuracies on target: jigsaw : 0.006024, class : 0.379518
# New epoch - lr: 0.001
# 0/22 of epoch 17/30 jigsaw : 2.897689, class : 1.130055 - acc jigsaw : 0.273438, class : 0.640625 [bs:128]
# 10/22 of epoch 17/30 jigsaw : 2.866877, class : 0.952296 - acc jigsaw : 0.265625, class : 0.695312 [bs:128]
# 20/22 of epoch 17/30 jigsaw : 2.913475, class : 0.933650 - acc jigsaw : 0.226562, class : 0.734375 [bs:128]
# Accuracies on target: jigsaw : 0.004016, class : 0.355422
# New epoch - lr: 0.001
# 0/22 of epoch 18/30 jigsaw : 2.862737, class : 1.103670 - acc jigsaw : 0.242188, class : 0.679688 [bs:128]
# 10/22 of epoch 18/30 jigsaw : 2.805323, class : 0.924718 - acc jigsaw : 0.257812, class : 0.718750 [bs:128]
# 20/22 of epoch 18/30 jigsaw : 2.859783, class : 1.014965 - acc jigsaw : 0.210938, class : 0.695312 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.341365
# New epoch - lr: 0.001
# 0/22 of epoch 19/30 jigsaw : 2.811958, class : 0.798839 - acc jigsaw : 0.281250, class : 0.773438 [bs:128]
# 10/22 of epoch 19/30 jigsaw : 2.793241, class : 0.936327 - acc jigsaw : 0.250000, class : 0.734375 [bs:128]
# 20/22 of epoch 19/30 jigsaw : 2.875069, class : 1.081015 - acc jigsaw : 0.242188, class : 0.703125 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.391566
# New epoch - lr: 0.001
# 0/22 of epoch 20/30 jigsaw : 2.794229, class : 0.976433 - acc jigsaw : 0.265625, class : 0.695312 [bs:128]
# 10/22 of epoch 20/30 jigsaw : 2.824345, class : 1.096955 - acc jigsaw : 0.257812, class : 0.695312 [bs:128]
# 20/22 of epoch 20/30 jigsaw : 2.803449, class : 0.769758 - acc jigsaw : 0.265625, class : 0.726562 [bs:128]
# Accuracies on target: jigsaw : 0.004016, class : 0.395582
# New epoch - lr: 0.001
# 0/22 of epoch 21/30 jigsaw : 2.805156, class : 0.987098 - acc jigsaw : 0.265625, class : 0.679688 [bs:128]
# 10/22 of epoch 21/30 jigsaw : 2.739030, class : 0.924032 - acc jigsaw : 0.343750, class : 0.773438 [bs:128]
# 20/22 of epoch 21/30 jigsaw : 2.716402, class : 0.894554 - acc jigsaw : 0.351562, class : 0.710938 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.387550
# New epoch - lr: 0.001
# 0/22 of epoch 22/30 jigsaw : 2.741044, class : 0.824857 - acc jigsaw : 0.296875, class : 0.796875 [bs:128]
# 10/22 of epoch 22/30 jigsaw : 2.730269, class : 0.779038 - acc jigsaw : 0.265625, class : 0.781250 [bs:128]
# 20/22 of epoch 22/30 jigsaw : 2.764310, class : 0.860008 - acc jigsaw : 0.250000, class : 0.765625 [bs:128]
# Accuracies on target: jigsaw : 0.004016, class : 0.409639
# New epoch - lr: 0.001
# 0/22 of epoch 23/30 jigsaw : 2.799130, class : 0.811255 - acc jigsaw : 0.257812, class : 0.757812 [bs:128]
# 10/22 of epoch 23/30 jigsaw : 2.727827, class : 0.900097 - acc jigsaw : 0.335938, class : 0.718750 [bs:128]
# 20/22 of epoch 23/30 jigsaw : 2.779992, class : 0.940115 - acc jigsaw : 0.265625, class : 0.687500 [bs:128]
# Accuracies on target: jigsaw : 0.006024, class : 0.379518
# New epoch - lr: 0.001
# 0/22 of epoch 24/30 jigsaw : 2.694530, class : 0.936594 - acc jigsaw : 0.296875, class : 0.726562 [bs:128]
# 10/22 of epoch 24/30 jigsaw : 2.635261, class : 0.768089 - acc jigsaw : 0.320312, class : 0.773438 [bs:128]
# 20/22 of epoch 24/30 jigsaw : 2.660388, class : 0.886228 - acc jigsaw : 0.328125, class : 0.750000 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.383534
# New epoch - lr: 0.001
# 0/22 of epoch 25/30 jigsaw : 2.577567, class : 0.779019 - acc jigsaw : 0.335938, class : 0.757812 [bs:128]
# 10/22 of epoch 25/30 jigsaw : 2.549439, class : 0.724284 - acc jigsaw : 0.429688, class : 0.757812 [bs:128]
# 20/22 of epoch 25/30 jigsaw : 2.767670, class : 0.799165 - acc jigsaw : 0.296875, class : 0.781250 [bs:128]
# Accuracies on target: jigsaw : 0.006024, class : 0.339357
# New epoch - lr: 0.001
# 0/22 of epoch 26/30 jigsaw : 2.761731, class : 0.778078 - acc jigsaw : 0.320312, class : 0.742188 [bs:128]
# 10/22 of epoch 26/30 jigsaw : 2.610824, class : 0.910752 - acc jigsaw : 0.351562, class : 0.734375 [bs:128]
# 20/22 of epoch 26/30 jigsaw : 2.741314, class : 0.865528 - acc jigsaw : 0.343750, class : 0.726562 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.369478
# New epoch - lr: 0.001
# 0/22 of epoch 27/30 jigsaw : 2.715584, class : 0.845814 - acc jigsaw : 0.234375, class : 0.765625 [bs:128]
# 10/22 of epoch 27/30 jigsaw : 2.548313, class : 0.908102 - acc jigsaw : 0.304688, class : 0.703125 [bs:128]
# 20/22 of epoch 27/30 jigsaw : 2.537738, class : 0.899992 - acc jigsaw : 0.281250, class : 0.710938 [bs:128]
# Accuracies on target: jigsaw : 0.000000, class : 0.409639
# New epoch - lr: 0.0001
# 0/22 of epoch 28/30 jigsaw : 2.459889, class : 0.606051 - acc jigsaw : 0.367188, class : 0.804688 [bs:128]
# 10/22 of epoch 28/30 jigsaw : 2.599938, class : 0.791142 - acc jigsaw : 0.406250, class : 0.750000 [bs:128]
# 20/22 of epoch 28/30 jigsaw : 2.638346, class : 0.946122 - acc jigsaw : 0.281250, class : 0.718750 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.383534
# New epoch - lr: 0.0001
# 0/22 of epoch 29/30 jigsaw : 2.680411, class : 0.560485 - acc jigsaw : 0.281250, class : 0.820312 [bs:128]
# 10/22 of epoch 29/30 jigsaw : 2.586060, class : 0.596119 - acc jigsaw : 0.351562, class : 0.828125 [bs:128]
# 20/22 of epoch 29/30 jigsaw : 2.508025, class : 0.829228 - acc jigsaw : 0.367188, class : 0.757812 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.367470
# New epoch - lr: 0.0001
# 0/22 of epoch 30/30 jigsaw : 2.638743, class : 0.656100 - acc jigsaw : 0.320312, class : 0.781250 [bs:128]
# 10/22 of epoch 30/30 jigsaw : 2.628926, class : 0.686207 - acc jigsaw : 0.328125, class : 0.765625 [bs:128]
# 20/22 of epoch 30/30 jigsaw : 2.533263, class : 0.573492 - acc jigsaw : 0.289062, class : 0.820312 [bs:128]
# Accuracies on target: jigsaw : 0.002008, class : 0.375502

# %%
def to_plt(inp):
    inp = inp.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    return inp

conv1 = models.alexnet(pretrained=True).features[0] #model_ft.features[0]
tmp = conv1.weight.cpu().data
tmp = torchvision.utils.make_grid(tmp,normalize=True)
plt.imshow(to_plt(tmp))
plt.show()

# %%
import numpy as np

conv1 = model_ft.features[0]
tmp = conv1.weight.cpu().data
tmp = torchvision.utils.make_grid(tmp,normalize=True)
plt.imshow(to_plt(tmp))
plt.show()

# %%
plt.plot(memory["train"], label="train")
plt.plot(memory["val"], label="val")
plt.show()

# %%
# iter_c = iter(train_datasets)

# for x in range(5):
#     tmp = next(iter_c)
#     image = to_plt(tmp[0])
#     plt.imshow(image)
#     plt.show()

# %%
from os.path import join, dirname
# from data.JigsawLoader import JigsawTestDataset
import torch
import matplotlib.pyplot as plt
import numpy as np


def to_plt(inp):
    inp = inp.numpy().transpose((1, 2, 0))
#     mean = np.array([0.485, 0.456, 0.406])
#     std = np.array([0.229, 0.224, 0.225])
#     inp = std * inp + mean
#     inp = np.clip(inp, 0, 1)
    return inp

# dataset = JigsawTestDataset("", join('data/txt_lists', 'dslr_train.txt'), patches=False, classes=31)
# test = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True, num_workers=4, pin_memory=True, drop_last=False)
iter_c = iter(dataloaders["train"])
(tmp, v, c), d = next(iter_c)
for x in range(5):
    image = tmp[x]
    image = torchvision.utils.make_grid(tmp[x],1,normalize=True)
    plt.imshow(to_plt(image))
    plt.show()
    print(v[x],c[x])
    
print(v.max(), v.min())

# %%
[d[d==k].shape for k in [0,1]]

# %%
from data.JigsawLoader import JigsawDataset
from PIL import Image
import torchvision.transforms as transforms

class JigsawTestDataset(JigsawDataset):
    def __init__(self, *args, **xargs):
        super().__init__(*args, **xargs)
        self._augment_tile = transforms.Compose([
#             transforms.RandomCrop(64),
            transforms.Resize((75, 75), Image.BILINEAR),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])
        
    def __getitem__(self, index):
        framename = self.data_path + '/' + self.names[index]
        img = Image.open(framename).convert('RGB')
        img = self._image_transformer(img)

        w = float(img.size[0]) / self.grid_size
        n_grids = self.grid_size ** 2
        tiles = [None] * n_grids
        for n in range(n_grids):
            y = int(n / self.grid_size)
            x = n % self.grid_size
            tile = img.crop([x * w, y * w, (x + 1) * w, (y + 1) * w])
            tile = self._augment_tile(tile)
            tiles[n] = tile

        data = torch.stack(tiles, 0)
        return self.returnFunc(data), 0, int(self.labels[index])

# %%
dataset = JigsawTestDataset("", join('data/txt_lists', 'dslr_train.txt'), patches=False, classes=31)
